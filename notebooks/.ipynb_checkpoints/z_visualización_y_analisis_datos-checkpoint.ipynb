# %%
import pandas as pd
import numpy as np
import glob

# %%
# Lectura de los archivos csv y guardado de todos los datos en un archivo único.
# Pongo dtype=object porque sale un warning porque hay types mixtos. Esto cambia todos los tipos a object
# aunque inicialmente puede ser mejor dejarlos como están ya que casi todas las columnas son float
# e interesa que sigan así.

#df1 = pd.read_csv('../data/raw/data_1.csv',dtype=object)
#df2 = pd.read_csv('../data/raw/data_all.csv', dtype=object)

df1 = pd.read_csv('../data/raw/data_1.csv')
df2 = pd.read_csv('../data/raw/data_all.csv')
list_df = [df2,df1]
data_all_parameters = pd.concat(list_df, ignore_index=False, axis=0, sort=False)
data_all_parameters.to_csv('../data/raw/data_all_parameters.csv')
data_all_parameters
# Out:
# /home/emilio/miniconda3/envs/test_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (2,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/emilio/miniconda3/envs/test_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (2,12,33,38,42,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              Date      Time New Device Time  BG Reading (mg/dL)  \
# 0      25/03/2020  23:10:52             NaN                 NaN
# 1      25/03/2020  23:10:52             NaN                 NaN
# 2      25/03/2020  23:10:52             NaN                 NaN
# 3      25/03/2020  23:10:52             NaN                 NaN
# 4      25/03/2020  23:04:32             NaN                 NaN
# ...           ...       ...             ...                 ...
# 38915  16/11/2015  15:22:14             NaN                 NaN
# 38916  16/11/2015  15:16:59             NaN                 NaN
# 38917  16/11/2015  15:16:55             NaN               165.0
# 38918  16/11/2015  15:16:55             NaN                 NaN
# 38919  16/11/2015  15:16:55             NaN                 NaN
#
#       Linked BG Meter ID  Basal Rate (U/h)  Temp Basal Amount Temp Basal Type  \
# 0                    NaN               NaN                NaN             NaN
# 1                    NaN              1.95                NaN             NaN
# 2                    NaN               NaN                NaN             NaN
# 3                    NaN               NaN                NaN             NaN
# 4                    NaN               NaN                NaN             NaN
# ...                  ...               ...                ...             ...
# 38915                NaN               NaN                NaN             NaN
# 38916                NaN               NaN                NaN             NaN
# 38917                NaN               NaN                NaN             NaN
# 38918                NaN               NaN                NaN             NaN
# 38919                NaN               NaN                NaN             NaN
#
#       Temp Basal Duration (h:mm:ss) Bolus Type  ...  Scroll Step Size  \
# 0                               NaN        NaN  ...               NaN
# 1                               NaN        NaN  ...               NaN
# 2                               NaN        NaN  ...               NaN
# 3                               NaN        NaN  ...               NaN
# 4                               NaN        NaN  ...               NaN
# ...                             ...        ...  ...               ...
# 38915                           NaN     Normal  ...               NaN
# 38916                           NaN     Normal  ...               NaN
# 38917                           NaN        NaN  ...               NaN
# 38918                           NaN        NaN  ...    STEP_0_POINT_1
# 38919                           NaN        NaN  ...               NaN
#
#        Insulin Action Curve Time Sensor Calibration Rejected Reason  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            NaN                                NaN
# 3                            NaN                                NaN
# 4                            NaN                                NaN
# ...                          ...                                ...
# 38915                        NaN                                NaN
# 38916                        NaN                                NaN
# 38917                        NaN                                NaN
# 38918                        NaN                                NaN
# 38919                        NaN                                NaN
#
#       Preset Bolus  Bolus Source Network Device Associated Reason  \
# 0              NaN           NaN                              NaN
# 1              NaN           NaN                              NaN
# 2              NaN           NaN                              NaN
# 3              NaN           NaN                              NaN
# 4              NaN           NaN                              NaN
# ...            ...           ...                              ...
# 38915          NaN  BOLUS_WIZARD                              NaN
# 38916          NaN  BOLUS_WIZARD                              NaN
# 38917          NaN           NaN                              NaN
# 38918          NaN           NaN                              NaN
# 38919          NaN           NaN                              NaN
#
#       Network Device Disassociated Reason Network Device Disconnected Reason  \
# 0                                     NaN                                NaN
# 1                                     NaN                                NaN
# 2                                     NaN                                NaN
# 3                                     NaN                                NaN
# 4                                     NaN                                NaN
# ...                                   ...                                ...
# 38915                                 NaN                                NaN
# 38916                                 NaN                                NaN
# 38917                                 NaN                                NaN
# 38918                                 NaN                                NaN
# 38919                                 NaN                                NaN
#
#        Sensor Exception  Preset Temp Basal Name
# 0                   NaN                     NaN
# 1                   NaN                     NaN
# 2                   NaN                     NaN
# 3                   NaN                     NaN
# 4                   NaN                     NaN
# ...                 ...                     ...
# 38915               NaN                     NaN
# 38916               NaN                     NaN
# 38917               NaN                     NaN
# 38918               NaN                     NaN
# 38919               NaN                     NaN
#
# [72536 rows x 46 columns]

# %%
data = data_all_parameters
data.dtypes
# Out:
# Date                                    object
# Time                                    object
# New Device Time                         object
# BG Reading (mg/dL)                     float64
# Linked BG Meter ID                      object
# Basal Rate (U/h)                       float64
# Temp Basal Amount                      float64
# Temp Basal Type                         object
# Temp Basal Duration (h:mm:ss)           object
# Bolus Type                              object
# Bolus Volume Selected (U)              float64
# Bolus Volume Delivered (U)             float64
# Bolus Duration (h:mm:ss)                object
# Prime Type                              object
# Prime Volume Delivered (U)             float64
# Alarm                                   object
# Suspend                                 object
# Rewind                                  object
# BWZ Estimate (U)                       float64
# BWZ Target High BG (mg/dL)             float64
# BWZ Target Low BG (mg/dL)              float64
# BWZ Carb Ratio (U/Ex)                  float64
# BWZ Insulin Sensitivity (mg/dL/U)      float64
# BWZ Carb Input (exchanges)             float64
# BWZ BG Input (mg/dL)                   float64
# BWZ Correction Estimate (U)            float64
# BWZ Food Estimate (U)                  float64
# BWZ Active Insulin (U)                 float64
# Sensor Calibration BG (mg/dL)          float64
# Sensor Glucose (mg/dL)                 float64
# ISIG Value                             float64
# Event Marker                            object
# Bolus Number                           float64
# Bolus Cancellation Reason               object
# BWZ Unabsorbed Insulin Total (U)       float64
# Final Bolus Estimate                   float64
# Scroll Step Size                        object
# Insulin Action Curve Time              float64
# Sensor Calibration Rejected Reason      object
# Preset Bolus                           float64
# Bolus Source                            object
# Network Device Associated Reason        object
# Network Device Disassociated Reason     object
# Network Device Disconnected Reason      object
# Sensor Exception                       float64
# Preset Temp Basal Name                  object
# dtype: object

# %%
data.columns.tolist()
# Out:
# ['Date',
#  'Time',
#  'New Device Time',
#  'BG Reading (mg/dL)',
#  'Linked BG Meter ID',
#  'Basal Rate (U/h)',
#  'Temp Basal Amount',
#  'Temp Basal Type',
#  'Temp Basal Duration (h:mm:ss)',
#  'Bolus Type',
#  'Bolus Volume Selected (U)',
#  'Bolus Volume Delivered (U)',
#  'Bolus Duration (h:mm:ss)',
#  'Prime Type',
#  'Prime Volume Delivered (U)',
#  'Alarm',
#  'Suspend',
#  'Rewind',
#  'BWZ Estimate (U)',
#  'BWZ Target High BG (mg/dL)',
#  'BWZ Target Low BG (mg/dL)',
#  'BWZ Carb Ratio (U/Ex)',
#  'BWZ Insulin Sensitivity (mg/dL/U)',
#  'BWZ Carb Input (exchanges)',
#  'BWZ BG Input (mg/dL)',
#  'BWZ Correction Estimate (U)',
#  'BWZ Food Estimate (U)',
#  'BWZ Active Insulin (U)',
#  'Sensor Calibration BG (mg/dL)',
#  'Sensor Glucose (mg/dL)',
#  'ISIG Value',
#  'Event Marker',
#  'Bolus Number',
#  'Bolus Cancellation Reason',
#  'BWZ Unabsorbed Insulin Total (U)',
#  'Final Bolus Estimate',
#  'Scroll Step Size',
#  'Insulin Action Curve Time',
#  'Sensor Calibration Rejected Reason',
#  'Preset Bolus',
#  'Bolus Source',
#  'Network Device Associated Reason',
#  'Network Device Disassociated Reason',
#  'Network Device Disconnected Reason',
#  'Sensor Exception',
#  'Preset Temp Basal Name']

# %%
# Se muestran los valores nulos

data.isnull().sum()
# Out:
# Date                                       0
# Time                                       0
# New Device Time                        72515
# BG Reading (mg/dL)                     63014
# Linked BG Meter ID                     67005
# Basal Rate (U/h)                       44119
# Temp Basal Amount                      71862
# Temp Basal Type                        71862
# Temp Basal Duration (h:mm:ss)          71862
# Bolus Type                             59447
# Bolus Volume Selected (U)              59477
# Bolus Volume Delivered (U)             66006
# Bolus Duration (h:mm:ss)               72509
# Prime Type                             71687
# Prime Volume Delivered (U)             71687
# Alarm                                  68442
# Suspend                                69677
# Rewind                                 72116
# BWZ Estimate (U)                       66179
# BWZ Target High BG (mg/dL)             66179
# BWZ Target Low BG (mg/dL)              66179
# BWZ Carb Ratio (U/Ex)                  66179
# BWZ Insulin Sensitivity (mg/dL/U)      66179
# BWZ Carb Input (exchanges)             66179
# BWZ BG Input (mg/dL)                   66179
# BWZ Correction Estimate (U)            66179
# BWZ Food Estimate (U)                  66179
# BWZ Active Insulin (U)                 66179
# Sensor Calibration BG (mg/dL)          72280
# Sensor Glucose (mg/dL)                 72536
# ISIG Value                             72536
# Event Marker                           72500
# Bolus Number                           59447
# Bolus Cancellation Reason              72506
# BWZ Unabsorbed Insulin Total (U)       66179
# Final Bolus Estimate                   66179
# Scroll Step Size                       66179
# Insulin Action Curve Time              72500
# Sensor Calibration Rejected Reason     72501
# Preset Bolus                           72536
# Bolus Source                           59477
# Network Device Associated Reason       72521
# Network Device Disassociated Reason    72526
# Network Device Disconnected Reason     72501
# Sensor Exception                       72536
# Preset Temp Basal Name                 71883
# dtype: int64

# %%
# Se muestran los % de valores nulos por columnas

null_cols = data.isnull().sum()

null_cols[null_cols > 0]
null_cols[null_cols > 0] / len(data) * 100
# Out:
# New Device Time                         99.971049
# BG Reading (mg/dL)                      86.872725
# Linked BG Meter ID                      92.374821
# Basal Rate (U/h)                        60.823591
# Temp Basal Amount                       99.070806
# Temp Basal Type                         99.070806
# Temp Basal Duration (h:mm:ss)           99.070806
# Bolus Type                              81.955167
# Bolus Volume Selected (U)               81.996526
# Bolus Volume Delivered (U)              90.997574
# Bolus Duration (h:mm:ss)                99.962777
# Prime Type                              98.829547
# Prime Volume Delivered (U)              98.829547
# Alarm                                   94.355906
# Suspend                                 96.058509
# Rewind                                  99.420977
# BWZ Estimate (U)                        91.236076
# BWZ Target High BG (mg/dL)              91.236076
# BWZ Target Low BG (mg/dL)               91.236076
# BWZ Carb Ratio (U/Ex)                   91.236076
# BWZ Insulin Sensitivity (mg/dL/U)       91.236076
# BWZ Carb Input (exchanges)              91.236076
# BWZ BG Input (mg/dL)                    91.236076
# BWZ Correction Estimate (U)             91.236076
# BWZ Food Estimate (U)                   91.236076
# BWZ Active Insulin (U)                  91.236076
# Sensor Calibration BG (mg/dL)           99.647072
# Sensor Glucose (mg/dL)                 100.000000
# ISIG Value                             100.000000
# Event Marker                            99.950369
# Bolus Number                            81.955167
# Bolus Cancellation Reason               99.958641
# BWZ Unabsorbed Insulin Total (U)        91.236076
# Final Bolus Estimate                    91.236076
# Scroll Step Size                        91.236076
# Insulin Action Curve Time               99.950369
# Sensor Calibration Rejected Reason      99.951748
# Preset Bolus                           100.000000
# Bolus Source                            81.996526
# Network Device Associated Reason        99.979321
# Network Device Disassociated Reason     99.986214
# Network Device Disconnected Reason      99.951748
# Sensor Exception                       100.000000
# Preset Temp Basal Name                  99.099757
# dtype: float64

# %%
import missingno

# %matplotlib inline

# it is necessary to sample data since otherwise the plot would be over-populated 
# se plotea diagrama de barras para ver en qué columnas hay mas nulos cogiendo 500 datos de muestra.
sample_data = data.sample(500, random_state=42)
missingno.bar(sample_data);

# %%
# Se definen drop_columns y se borran.
drop_columns = ['New Device Time', 'BG Reading (mg/dL)',\
                'Linked BG Meter ID', 'Temp Basal Amount',\
                'Temp Basal Type', 'Temp Basal Duration (h:mm:ss)', 'Bolus Type',\
                'Bolus Volume Selected (U)', 'Bolus Volume Delivered (U)',\
                'Bolus Duration (h:mm:ss)', 'Prime Type', 'Prime Volume Delivered (U)',\
                'Alarm', 'Suspend', 'Rewind', \
                'BWZ Target High BG (mg/dL)', 'BWZ Target Low BG (mg/dL)',\
                'Sensor Calibration BG (mg/dL)',\
                'Sensor Glucose (mg/dL)', 'ISIG Value', 'Event Marker', 'Bolus Number',\
                'Bolus Cancellation Reason',\
                'Final Bolus Estimate', 'Scroll Step Size', 'Insulin Action Curve Time',\
                'Sensor Calibration Rejected Reason', 'Preset Bolus', 'Bolus Source',\
                'Network Device Associated Reason',\
                'Network Device Disassociated Reason',\
                'Network Device Disconnected Reason', 'Sensor Exception',\
                'Preset Temp Basal Name']
data_cols_goods = data.drop(drop_columns, axis=1)
data_cols_goods
# Out:
#              Date      Time  Basal Rate (U/h)  BWZ Estimate (U)  \
# 0      25/03/2020  23:10:52               NaN               NaN
# 1      25/03/2020  23:10:52              1.95               NaN
# 2      25/03/2020  23:10:52               NaN               NaN
# 3      25/03/2020  23:10:52               NaN               NaN
# 4      25/03/2020  23:04:32               NaN               NaN
# ...           ...       ...               ...               ...
# 38915  16/11/2015  15:22:14               NaN               NaN
# 38916  16/11/2015  15:16:59               NaN               NaN
# 38917  16/11/2015  15:16:55               NaN               NaN
# 38918  16/11/2015  15:16:55               NaN               NaN
# 38919  16/11/2015  15:16:55               NaN               7.9
#
#        BWZ Carb Ratio (U/Ex)  BWZ Insulin Sensitivity (mg/dL/U)  \
# 0                        NaN                                NaN
# 1                        NaN                                NaN
# 2                        NaN                                NaN
# 3                        NaN                                NaN
# 4                        NaN                                NaN
# ...                      ...                                ...
# 38915                    NaN                                NaN
# 38916                    NaN                                NaN
# 38917                    NaN                                NaN
# 38918                    NaN                                NaN
# 38919                    1.0                               50.0
#
#        BWZ Carb Input (exchanges)  BWZ BG Input (mg/dL)  \
# 0                             NaN                   NaN
# 1                             NaN                   NaN
# 2                             NaN                   NaN
# 3                             NaN                   NaN
# 4                             NaN                   NaN
# ...                           ...                   ...
# 38915                         NaN                   NaN
# 38916                         NaN                   NaN
# 38917                         NaN                   NaN
# 38918                         NaN                   NaN
# 38919                         7.0                 165.0
#
#        BWZ Correction Estimate (U)  BWZ Food Estimate (U)  \
# 0                              NaN                    NaN
# 1                              NaN                    NaN
# 2                              NaN                    NaN
# 3                              NaN                    NaN
# 4                              NaN                    NaN
# ...                            ...                    ...
# 38915                          NaN                    NaN
# 38916                          NaN                    NaN
# 38917                          NaN                    NaN
# 38918                          NaN                    NaN
# 38919                          0.9                    7.0
#
#        BWZ Active Insulin (U)  BWZ Unabsorbed Insulin Total (U)
# 0                         NaN                               NaN
# 1                         NaN                               NaN
# 2                         NaN                               NaN
# 3                         NaN                               NaN
# 4                         NaN                               NaN
# ...                       ...                               ...
# 38915                     NaN                               NaN
# 38916                     NaN                               NaN
# 38917                     NaN                               NaN
# 38918                     NaN                               0.0
# 38919                     0.0                               NaN
#
# [72536 rows x 12 columns]

# %%
# Rellenamos los valores nulos de las columnas según los valores que hay por encima.
# Por el orden en el que salen en el archivo csv necesitamos hacer foward fill (ffill) a BWZ Unabsorbed
# insulin Total(U/h)
# y necesitamos hacer back fill (bfill) a la columna de Basal Rate (U/h)


data_cols_goods['Basal Rate (U/h)'] = data_cols_goods['Basal Rate (U/h)'].fillna(method ='bfill')
data_cols_goods['BWZ Unabsorbed Insulin Total (U)']= \
                data_cols_goods['BWZ Unabsorbed Insulin Total (U)'].fillna(method ='ffill')
data_cols_goods
# Out:
#              Date      Time  Basal Rate (U/h)  BWZ Estimate (U)  \
# 0      25/03/2020  23:10:52              1.95               NaN
# 1      25/03/2020  23:10:52              1.95               NaN
# 2      25/03/2020  23:10:52              0.00               NaN
# 3      25/03/2020  23:10:52              0.00               NaN
# 4      25/03/2020  23:04:32              0.00               NaN
# ...           ...       ...               ...               ...
# 38915  16/11/2015  15:22:14               NaN               NaN
# 38916  16/11/2015  15:16:59               NaN               NaN
# 38917  16/11/2015  15:16:55               NaN               NaN
# 38918  16/11/2015  15:16:55               NaN               NaN
# 38919  16/11/2015  15:16:55               NaN               7.9
#
#        BWZ Carb Ratio (U/Ex)  BWZ Insulin Sensitivity (mg/dL/U)  \
# 0                        NaN                                NaN
# 1                        NaN                                NaN
# 2                        NaN                                NaN
# 3                        NaN                                NaN
# 4                        NaN                                NaN
# ...                      ...                                ...
# 38915                    NaN                                NaN
# 38916                    NaN                                NaN
# 38917                    NaN                                NaN
# 38918                    NaN                                NaN
# 38919                    1.0                               50.0
#
#        BWZ Carb Input (exchanges)  BWZ BG Input (mg/dL)  \
# 0                             NaN                   NaN
# 1                             NaN                   NaN
# 2                             NaN                   NaN
# 3                             NaN                   NaN
# 4                             NaN                   NaN
# ...                           ...                   ...
# 38915                         NaN                   NaN
# 38916                         NaN                   NaN
# 38917                         NaN                   NaN
# 38918                         NaN                   NaN
# 38919                         7.0                 165.0
#
#        BWZ Correction Estimate (U)  BWZ Food Estimate (U)  \
# 0                              NaN                    NaN
# 1                              NaN                    NaN
# 2                              NaN                    NaN
# 3                              NaN                    NaN
# 4                              NaN                    NaN
# ...                            ...                    ...
# 38915                          NaN                    NaN
# 38916                          NaN                    NaN
# 38917                          NaN                    NaN
# 38918                          NaN                    NaN
# 38919                          0.9                    7.0
#
#        BWZ Active Insulin (U)  BWZ Unabsorbed Insulin Total (U)
# 0                         NaN                               NaN
# 1                         NaN                               NaN
# 2                         NaN                               NaN
# 3                         NaN                               NaN
# 4                         NaN                               NaN
# ...                       ...                               ...
# 38915                     NaN                               0.8
# 38916                     NaN                               0.8
# 38917                     NaN                               0.8
# 38918                     NaN                               0.0
# 38919                     0.0                               0.0
#
# [72536 rows x 12 columns]

# %%
# Eliminamos filas que están repetidas
data_cols_goods.duplicated().sum()
# Out:
# 16599

# %%
# Se eliminan las filas con nulos
data_without_nulls = data_cols_goods.dropna()
data_without_nulls
# Out:
#              Date      Time  Basal Rate (U/h)  BWZ Estimate (U)  \
# 16     25/03/2020  22:18:54              1.95               9.5
# 60     25/03/2020   8:35:19              1.60               6.6
# 82     24/03/2020  22:26:09              1.95               5.5
# 103    24/03/2020  18:35:33              2.70               4.4
# 118    24/03/2020  15:20:03              2.20              11.2
# ...           ...       ...               ...               ...
# 38868  17/11/2015  14:21:04              0.40               9.5
# 38873  17/11/2015  12:22:57              0.40               3.0
# 38887  17/11/2015   7:40:19              0.40               2.4
# 38898  16/11/2015  21:34:04              0.60               8.7
# 38912  16/11/2015  18:49:17              0.55               3.5
#
#        BWZ Carb Ratio (U/Ex)  BWZ Insulin Sensitivity (mg/dL/U)  \
# 16                       1.0                               45.0
# 60                       1.9                               45.0
# 82                       1.0                               45.0
# 103                      1.1                               45.0
# 118                      1.5                               45.0
# ...                      ...                                ...
# 38868                    1.0                               50.0
# 38873                    1.0                               50.0
# 38887                    0.8                               50.0
# 38898                    1.0                               50.0
# 38912                    1.0                               50.0
#
#        BWZ Carb Input (exchanges)  BWZ BG Input (mg/dL)  \
# 16                            9.5                  84.0
# 60                            3.5                 111.0
# 82                            5.5                  99.0
# 103                           4.0                  97.0
# 118                           7.5                  75.0
# ...                           ...                   ...
# 38868                         9.5                 126.0
# 38873                         3.0                 103.0
# 38887                         3.0                 101.0
# 38898                         8.5                 173.0
# 38912                         1.5                 264.0
#
#        BWZ Correction Estimate (U)  BWZ Food Estimate (U)  \
# 16                             0.0                    9.5
# 60                             0.0                    6.6
# 82                             0.0                    5.5
# 103                            0.0                    4.4
# 118                            0.0                   11.2
# ...                            ...                    ...
# 38868                          0.1                    9.5
# 38873                          0.0                    3.0
# 38887                          0.0                    2.4
# 38898                          1.0                    8.5
# 38912                          2.8                    1.5
#
#        BWZ Active Insulin (U)  BWZ Unabsorbed Insulin Total (U)
# 16                        0.0                               0.0
# 60                        0.0                               0.0
# 82                        0.0                               0.0
# 103                       1.2                               0.0
# 118                       0.0                               0.0
# ...                       ...                               ...
# 38868                     1.3                               0.1
# 38873                     0.0                               0.0
# 38887                     0.0                               0.0
# 38898                     0.8                               0.8
# 38912                     0.8                               0.8
#
# [6356 rows x 12 columns]

# %%
# Para poder utilizar los valores de la columna Date y Time después hay que pasarlos a formato 'datetime' 
data_without_nulls['Date'] = pd.to_datetime(data_without_nulls['Date'])
data_without_nulls['Time'] = pd.to_datetime(data_without_nulls['Time'])
# Out:
# /home/emilio/miniconda3/envs/test_env/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/emilio/miniconda3/envs/test_env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#data_cols_goods.fillna(axis = 0, method = 'ffill')
#data_cols_goods.to_csv('data_cols_goods.csv')

# %%
data_without_nulls['day_of_month'] = data_without_nulls['Date'].dt.day
data_without_nulls['day_of_week'] = data_without_nulls['Date'].dt.dayofweek
data_without_nulls['month_of_year'] = data_without_nulls['Date'].dt.month
data_without_nulls['hour'] = data_without_nulls['Time'].dt.hour

data_without_nulls.to_csv('a.csv')

data_without_nulls .dtypes
# Out:
# /home/emilio/miniconda3/envs/test_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/emilio/miniconda3/envs/test_env/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/emilio/miniconda3/envs/test_env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/emilio/miniconda3/envs/test_env/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Date                                 datetime64[ns]
# Time                                 datetime64[ns]
# Basal Rate (U/h)                            float64
# BWZ Estimate (U)                            float64
# BWZ Carb Ratio (U/Ex)                       float64
# BWZ Insulin Sensitivity (mg/dL/U)           float64
# BWZ Carb Input (exchanges)                  float64
# BWZ BG Input (mg/dL)                        float64
# BWZ Correction Estimate (U)                 float64
# BWZ Food Estimate (U)                       float64
# BWZ Active Insulin (U)                      float64
# BWZ Unabsorbed Insulin Total (U)            float64
# day_of_month                                  int64
# day_of_week                                   int64
# month_of_year                                 int64
# hour                                          int64
# dtype: object

# %%
data_without_nulls.describe().T
# Out:
#                                     count        mean        std   min  \
# Basal Rate (U/h)                   6356.0    0.893022   0.293308   0.0
# BWZ Estimate (U)                   6356.0    4.799481   2.619866   0.0
# BWZ Carb Ratio (U/Ex)              6356.0    0.877302   0.178301   0.5
# BWZ Insulin Sensitivity (mg/dL/U)  6356.0   49.457992   2.238979  40.0
# BWZ Carb Input (exchanges)         6356.0    5.044053   2.782070   0.0
# BWZ BG Input (mg/dL)               6356.0  133.803335  68.345047   0.0
# BWZ Correction Estimate (U)        6356.0    0.541347   1.052215  -0.5
# BWZ Food Estimate (U)              6356.0    4.398348   2.610547   0.0
# BWZ Active Insulin (U)             6356.0    0.474622   0.984862   0.0
# BWZ Unabsorbed Insulin Total (U)   6356.0    0.140356   0.442569   0.0
# day_of_month                       6356.0   15.632316   8.931400   1.0
# day_of_week                        6356.0    2.980648   2.020533   0.0
# month_of_year                      6356.0    6.337476   3.573024   1.0
# hour                               6356.0   14.746381   5.521108   0.0
#
#                                       25%     50%    75%    max
# Basal Rate (U/h)                     0.70    0.90    1.0    2.7
# BWZ Estimate (U)                     2.70    4.40    6.6   18.0
# BWZ Carb Ratio (U/Ex)                0.78    0.83    1.0    1.9
# BWZ Insulin Sensitivity (mg/dL/U)   50.00   50.00   50.0   50.0
# BWZ Carb Input (exchanges)           3.00    5.00    7.5   12.5
# BWZ BG Input (mg/dL)               100.00  105.00  162.0  542.0
# BWZ Correction Estimate (U)          0.00    0.00    0.7    8.4
# BWZ Food Estimate (U)                2.40    4.00    6.3   18.0
# BWZ Active Insulin (U)               0.00    0.00    0.5   10.3
# BWZ Unabsorbed Insulin Total (U)     0.00    0.00    0.0    5.8
# day_of_month                         8.00   16.00   23.0   31.0
# day_of_week                          1.00    3.00    5.0    6.0
# month_of_year                        3.00    6.00    9.0   12.0
# hour                                11.00   15.00   19.0   23.0

# %%
# Se cuenta el número de duplicados
data_without_nulls.duplicated().sum()
# Out:
# 0

# %%
filter_low_index = data_without_nulls['BWZ BG Input (mg/dL)'] < 70
filter_high_index = data_without_nulls['BWZ BG Input (mg/dL)'] > 140

# %%
sum(filter_low_index)
# Out:
# 244

# %%
sum(filter_high_index)
# Out:
# 2074

# %%
# Eliminamos datos que no son buenos para realizar el entrenamiento, es decir, datos de lectura
# de niveles de insulina altos o bajos.

Data = data_without_nulls[~(filter_low_index | filter_high_index)]
Data.max()
# Out:
# Date                                 2020-12-03 00:00:00
# Time                                 2020-04-07 23:59:05
# Basal Rate (U/h)                                     2.7
# BWZ Estimate (U)                                      18
# BWZ Carb Ratio (U/Ex)                                1.9
# BWZ Insulin Sensitivity (mg/dL/U)                     50
# BWZ Carb Input (exchanges)                          12.5
# BWZ BG Input (mg/dL)                                 140
# BWZ Correction Estimate (U)                          0.4
# BWZ Food Estimate (U)                                 18
# BWZ Active Insulin (U)                               9.8
# BWZ Unabsorbed Insulin Total (U)                     0.4
# day_of_month                                          31
# day_of_week                                            6
# month_of_year                                         12
# hour                                                  23
# dtype: object

# %%
Data.corr()
# Out:
#                                    Basal Rate (U/h)  BWZ Estimate (U)  \
# Basal Rate (U/h)                           1.000000          0.133947
# BWZ Estimate (U)                           0.133947          1.000000
# BWZ Carb Ratio (U/Ex)                      0.357882          0.376667
# BWZ Insulin Sensitivity (mg/dL/U)         -0.519004         -0.319346
# BWZ Carb Input (exchanges)                -0.011075          0.899423
# BWZ BG Input (mg/dL)                       0.027332          0.005378
# BWZ Correction Estimate (U)               -0.077546          0.018479
# BWZ Food Estimate (U)                      0.135003          0.999869
# BWZ Active Insulin (U)                     0.122522         -0.026865
# BWZ Unabsorbed Insulin Total (U)          -0.042164          0.029095
# day_of_month                              -0.051349         -0.009255
# day_of_week                               -0.007340          0.047607
# month_of_year                             -0.140575         -0.065423
# hour                                      -0.100398          0.240575
#
#                                    BWZ Carb Ratio (U/Ex)  \
# Basal Rate (U/h)                                0.357882
# BWZ Estimate (U)                                0.376667
# BWZ Carb Ratio (U/Ex)                           1.000000
# BWZ Insulin Sensitivity (mg/dL/U)              -0.558789
# BWZ Carb Input (exchanges)                     -0.026901
# BWZ BG Input (mg/dL)                            0.017754
# BWZ Correction Estimate (U)                     0.025611
# BWZ Food Estimate (U)                           0.376601
# BWZ Active Insulin (U)                         -0.023677
# BWZ Unabsorbed Insulin Total (U)                0.038610
# day_of_month                                   -0.030782
# day_of_week                                    -0.028439
# month_of_year                                  -0.130963
# hour                                           -0.250362
#
#                                    BWZ Insulin Sensitivity (mg/dL/U)  \
# Basal Rate (U/h)                                           -0.519004
# BWZ Estimate (U)                                           -0.319346
# BWZ Carb Ratio (U/Ex)                                      -0.558789
# BWZ Insulin Sensitivity (mg/dL/U)                           1.000000
# BWZ Carb Input (exchanges)                                 -0.066684
# BWZ BG Input (mg/dL)                                       -0.038928
# BWZ Correction Estimate (U)                                 0.049376
# BWZ Food Estimate (U)                                      -0.319927
# BWZ Active Insulin (U)                                     -0.107205
# BWZ Unabsorbed Insulin Total (U)                            0.031096
# day_of_month                                                0.014684
# day_of_week                                                 0.006237
# month_of_year                                               0.170474
# hour                                                        0.006988
#
#                                    BWZ Carb Input (exchanges)  \
# Basal Rate (U/h)                                    -0.011075
# BWZ Estimate (U)                                     0.899423
# BWZ Carb Ratio (U/Ex)                               -0.026901
# BWZ Insulin Sensitivity (mg/dL/U)                   -0.066684
# BWZ Carb Input (exchanges)                           1.000000
# BWZ BG Input (mg/dL)                                -0.007388
# BWZ Correction Estimate (U)                         -0.007008
# BWZ Food Estimate (U)                                0.899522
# BWZ Active Insulin (U)                              -0.046630
# BWZ Unabsorbed Insulin Total (U)                     0.005302
# day_of_month                                         0.004228
# day_of_week                                          0.062458
# month_of_year                                       -0.008598
# hour                                                 0.343386
#
#                                    BWZ BG Input (mg/dL)  \
# Basal Rate (U/h)                               0.027332
# BWZ Estimate (U)                               0.005378
# BWZ Carb Ratio (U/Ex)                          0.017754
# BWZ Insulin Sensitivity (mg/dL/U)             -0.038928
# BWZ Carb Input (exchanges)                    -0.007388
# BWZ BG Input (mg/dL)                           1.000000
# BWZ Correction Estimate (U)                    0.468399
# BWZ Food Estimate (U)                         -0.000521
# BWZ Active Insulin (U)                         0.077998
# BWZ Unabsorbed Insulin Total (U)               0.297239
# day_of_month                                   0.005860
# day_of_week                                   -0.019316
# month_of_year                                  0.001334
# hour                                          -0.010156
#
#                                    BWZ Correction Estimate (U)  \
# Basal Rate (U/h)                                     -0.077546
# BWZ Estimate (U)                                      0.018479
# BWZ Carb Ratio (U/Ex)                                 0.025611
# BWZ Insulin Sensitivity (mg/dL/U)                     0.049376
# BWZ Carb Input (exchanges)                           -0.007008
# BWZ BG Input (mg/dL)                                  0.468399
# BWZ Correction Estimate (U)                           1.000000
# BWZ Food Estimate (U)                                 0.006123
# BWZ Active Insulin (U)                                0.007848
# BWZ Unabsorbed Insulin Total (U)                      0.651861
# day_of_month                                         -0.010476
# day_of_week                                           0.016903
# month_of_year                                        -0.017092
# hour                                                 -0.009090
#
#                                    BWZ Food Estimate (U)  \
# Basal Rate (U/h)                                0.135003
# BWZ Estimate (U)                                0.999869
# BWZ Carb Ratio (U/Ex)                           0.376601
# BWZ Insulin Sensitivity (mg/dL/U)              -0.319927
# BWZ Carb Input (exchanges)                      0.899522
# BWZ BG Input (mg/dL)                           -0.000521
# BWZ Correction Estimate (U)                     0.006123
# BWZ Food Estimate (U)                           1.000000
# BWZ Active Insulin (U)                         -0.025680
# BWZ Unabsorbed Insulin Total (U)                0.028956
# day_of_month                                   -0.009098
# day_of_week                                     0.047244
# month_of_year                                  -0.065435
# hour                                            0.241235
#
#                                    BWZ Active Insulin (U)  \
# Basal Rate (U/h)                                 0.122522
# BWZ Estimate (U)                                -0.026865
# BWZ Carb Ratio (U/Ex)                           -0.023677
# BWZ Insulin Sensitivity (mg/dL/U)               -0.107205
# BWZ Carb Input (exchanges)                      -0.046630
# BWZ BG Input (mg/dL)                             0.077998
# BWZ Correction Estimate (U)                      0.007848
# BWZ Food Estimate (U)                           -0.025680
# BWZ Active Insulin (U)                           1.000000
# BWZ Unabsorbed Insulin Total (U)                 0.097956
# day_of_month                                    -0.025265
# day_of_week                                     -0.025446
# month_of_year                                   -0.062546
# hour                                             0.113078
#
#                                    BWZ Unabsorbed Insulin Total (U)  \
# Basal Rate (U/h)                                          -0.042164
# BWZ Estimate (U)                                           0.029095
# BWZ Carb Ratio (U/Ex)                                      0.038610
# BWZ Insulin Sensitivity (mg/dL/U)                          0.031096
# BWZ Carb Input (exchanges)                                 0.005302
# BWZ BG Input (mg/dL)                                       0.297239
# BWZ Correction Estimate (U)                                0.651861
# BWZ Food Estimate (U)                                      0.028956
# BWZ Active Insulin (U)                                     0.097956
# BWZ Unabsorbed Insulin Total (U)                           1.000000
# day_of_month                                              -0.004912
# day_of_week                                                0.000297
# month_of_year                                             -0.028028
# hour                                                       0.036215
#
#                                    day_of_month  day_of_week  month_of_year  \
# Basal Rate (U/h)                      -0.051349    -0.007340      -0.140575
# BWZ Estimate (U)                      -0.009255     0.047607      -0.065423
# BWZ Carb Ratio (U/Ex)                 -0.030782    -0.028439      -0.130963
# BWZ Insulin Sensitivity (mg/dL/U)      0.014684     0.006237       0.170474
# BWZ Carb Input (exchanges)             0.004228     0.062458      -0.008598
# BWZ BG Input (mg/dL)                   0.005860    -0.019316       0.001334
# BWZ Correction Estimate (U)           -0.010476     0.016903      -0.017092
# BWZ Food Estimate (U)                 -0.009098     0.047244      -0.065435
# BWZ Active Insulin (U)                -0.025265    -0.025446      -0.062546
# BWZ Unabsorbed Insulin Total (U)      -0.004912     0.000297      -0.028028
# day_of_month                           1.000000    -0.047211      -0.025904
# day_of_week                           -0.047211     1.000000      -0.015431
# month_of_year                         -0.025904    -0.015431       1.000000
# hour                                   0.011569     0.005971       0.002672
#
#                                        hour
# Basal Rate (U/h)                  -0.100398
# BWZ Estimate (U)                   0.240575
# BWZ Carb Ratio (U/Ex)             -0.250362
# BWZ Insulin Sensitivity (mg/dL/U)  0.006988
# BWZ Carb Input (exchanges)         0.343386
# BWZ BG Input (mg/dL)              -0.010156
# BWZ Correction Estimate (U)       -0.009090
# BWZ Food Estimate (U)              0.241235
# BWZ Active Insulin (U)             0.113078
# BWZ Unabsorbed Insulin Total (U)   0.036215
# day_of_month                       0.011569
# day_of_week                        0.005971
# month_of_year                      0.002672
# hour                               1.000000

# %%
# Plot datos sin filtros
data_cols_goods['BWZ BG Input (mg/dL)'].hist(figsize=(10, 5), bins=50);

# %%
# Plot datos con filtro, eliminadas las lecturas bjas y altas de glucosa en sangre
Data['BWZ BG Input (mg/dL)'].hist(figsize=(20, 10), bins=100);

# %%
#Carbohidrados tomados por raciones
Data['BWZ Carb Input (exchanges)'].hist(figsize=(8, 4), bins=100);

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import set_matplotlib_formats

set_matplotlib_formats('svg')
sns.set_style('whitegrid')

# %%
sns.distplot(Data['BWZ Carb Input (exchanges)'], bins=50);

# %%
fig = plt.figure(figsize=(8, 4))
ax = sns.barplot(x='hour', y='BWZ Carb Input (exchanges)', data=Data)

# %%
fig = plt.figure(figsize=(8, 4))
ax = sns.barplot(x='hour', y='BWZ Carb Input (exchanges)',hue='day_of_week', data=Data)

# %%
# Plot de correlación son seaborn metodo de spearman
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1, 1, 1)

sns.heatmap(Data.corr(method='spearman'), annot=True, fmt='.2f', ax=ax);

# %% [markdown]
# ## Según la tabla de correlación, habría que eliminar la columna de BWZ Food Estimate (U)
#
# * Pero ¿LA COLUMNA DE Carb Input (exchanges)? es una columna de correlación 0.94 y si la elimino el modelo predeciría la insulina a administrar sin tener en cuenta los carbohidratos que se comen, ¿qué es mejor?
