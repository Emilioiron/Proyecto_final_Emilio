# %%
import pandas as pd
import numpy as np
import glob

# %%
df1 = pd.read_csv('../data/raw/data_1.csv')
df2 = pd.read_csv('../data/raw/data_all.csv')
list_df = [df2,df1]
data_all_parameters = pd.concat(list_df, ignore_index=False, axis=1, sort=False)
data_all_parameters.to_csv('../data/raw/data_all_parameters.csv')
data_all_parameters
# Out:
#              Date      Time   New Device Time BG Reading (mg/dL)  \
# 0      25/03/2020  23:10:52               NaN                NaN
# 1      25/03/2020  23:10:52               NaN                NaN
# 2      25/03/2020  23:10:52               NaN                NaN
# 3      25/03/2020  23:10:52               NaN                NaN
# 4      25/03/2020  23:04:32               NaN                NaN
# ...           ...       ...               ...                ...
# 49489  28/02/2017  16:29:59               NaN                NaN
# 49490  28/02/2017  16:22:01               NaN                NaN
# 49491  28/02/2017  16:21:40               NaN                NaN
# 49492  28/02/2017  16:21:40               NaN                NaN
# 49493  28/02/2017  16:21:40  28/02/2017 16:21                NaN
#
#       Linked BG Meter ID Basal Rate (U/h) Temp Basal Amount Temp Basal Type  \
# 0                    NaN              NaN               NaN             NaN
# ...

# %%
# Leemos los archivos en csv e indicamos que la separación está por ';' para poder visualizarlo bien.
# Primero especificamos un patrón del archivo y lo pasamos como parámetro en la función glob
csv_files = glob.glob('../data/raw/*.csv')
# Mostrar el archivo csv_files, el cual es una lista de nombres
print(csv_files)
# Out:
# ['../data/raw/data_2.csv', '../data/raw/data_5.csv', '../data/raw/data_4.csv', '../data/raw/data_7.csv', '../data/raw/data_3.csv', '../data/raw/data_6.csv', '../data/raw/data_1.csv', '../data/raw/data_all_parameters.csv', '../data/raw/data_all.csv']

# %%
# función para añadir todos los archivos a una lista y concatenarlos

list_data = []
  
# Escribimos un loop que irá a través de cada uno de los nombres de archivo a través de globbing y el resultado final será la lista dataframes
def read_all_files(lista_de_nombres):
    for filename in csv_files:
        data = pd.read_csv(filename)
        list_data.append(data)
        #Para chequear que todo está bien, mostramos la list_data por consola
        return
read_all_files(csv_files)
list_data
# Out:
# [             Date      Time   New Device Time BG Reading (mg/dL)  \
#  0      26/09/2018  22:30:08               NaN                NaN
#  1      26/09/2018  22:29:11               NaN                NaN
#  2      26/09/2018  22:29:10               NaN                NaN
#  3      26/09/2018  22:29:10               NaN                NaN
#  4      26/09/2018  22:26:44               NaN             145.00
#  ...           ...       ...               ...                ...
#  22872  28/02/2017  16:29:59               NaN                NaN
#  22873  28/02/2017  16:22:01               NaN                NaN
#  22874  28/02/2017  16:21:40               NaN                NaN
#  22875  28/02/2017  16:21:40               NaN                NaN
#  22876  28/02/2017  16:21:40  28/02/2017 16:21                NaN
#
#        Linked BG Meter ID Basal Rate (U/h) Temp Basal Amount Temp Basal Type  \
#  0                    NaN              NaN               NaN             NaN
# ...

# %%
data_all_parameters_glob = pd.concat(list_data, ignore_index=False, axis=1, sort=False)
data_all_parameters_glob
# Out:
#              Date      Time   New Device Time BG Reading (mg/dL)  \
# 0      26/09/2018  22:30:08               NaN                NaN
# 1      26/09/2018  22:29:11               NaN                NaN
# 2      26/09/2018  22:29:10               NaN                NaN
# 3      26/09/2018  22:29:10               NaN                NaN
# 4      26/09/2018  22:26:44               NaN             145.00
# ...           ...       ...               ...                ...
# 22872  28/02/2017  16:29:59               NaN                NaN
# 22873  28/02/2017  16:22:01               NaN                NaN
# 22874  28/02/2017  16:21:40               NaN                NaN
# 22875  28/02/2017  16:21:40               NaN                NaN
# 22876  28/02/2017  16:21:40  28/02/2017 16:21                NaN
#
#       Linked BG Meter ID Basal Rate (U/h) Temp Basal Amount Temp Basal Type  \
# 0                    NaN              NaN               NaN             NaN
# ...

# %%
data_all_parameters.dtypes
# Out:
# Date                                   object
# Time                                   object
# New Device Time                        object
# BG Reading (mg/dL)                     object
# Linked BG Meter ID                     object
# Basal Rate (U/h)                       object
# Temp Basal Amount                      object
# Temp Basal Type                        object
# Temp Basal Duration (h:mm:ss)          object
# Bolus Type                             object
# Bolus Volume Selected (U)              object
# Bolus Volume Delivered (U)             object
# Bolus Duration (h:mm:ss)               object
# Prime Type                             object
# Prime Volume Delivered (U)             object
# Alarm                                  object
# Suspend                                object
# Rewind                                 object
# BWZ Estimate (U)                       object
# BWZ Target High BG (mg/dL)             object
# ...

# %%
# data_all_parameters["Date"]=pd.to_datetime(data_all_parameters["Date"])

data_all_parameters.to_csv('../data/processed/data_all_parameters.csv')
# Out:
#              Date      Time   New Device Time BG Reading (mg/dL)  \
# 0      26/09/2018  22:30:08               NaN                NaN
# 1      26/09/2018  22:29:11               NaN                NaN
# 2      26/09/2018  22:29:10               NaN                NaN
# 3      26/09/2018  22:29:10               NaN                NaN
# 4      26/09/2018  22:26:44               NaN             145.00
# ...           ...       ...               ...                ...
# 22872  28/02/2017  16:29:59               NaN                NaN
# 22873  28/02/2017  16:22:01               NaN                NaN
# 22874  28/02/2017  16:21:40               NaN                NaN
# 22875  28/02/2017  16:21:40               NaN                NaN
# 22876  28/02/2017  16:21:40  28/02/2017 16:21                NaN
#
#       Linked BG Meter ID Basal Rate (U/h) Temp Basal Amount Temp Basal Type  \
# 0                    NaN              NaN               NaN             NaN
# ...
