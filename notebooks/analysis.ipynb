# %%
import pandas as pd

# %%
Data = pd.read_csv('../data/processed/Data.csv')

# %%
Data
# Out:
#       Unnamed: 0  Unnamed: 0.1  Basal Rate (U/h)  BWZ Estimate (U)  \
# 0              0            16              1.95               9.5
# 1              1            60              1.60               6.6
# 2              2            82              1.95               5.5
# 3              3           103              2.70               4.4
# 4              4           118              2.20              11.2
# ...          ...           ...               ...               ...
# 4033        4033         38847              0.60               5.8
# 4034        4034         38861              0.55               4.0
# 4035        4035         38868              0.40               9.5
# 4036        4036         38873              0.40               3.0
# 4037        4037         38887              0.40               2.4
#
#       BWZ Carb Ratio (U/Ex)  BWZ Insulin Sensitivity (mg/dL/U)  \
# 0                       1.0                               45.0
# ...

# %%
# Se muestran los valores nulos

Data.isnull().sum()
# Out:
# Unnamed: 0                           0
# Unnamed: 0.1                         0
# Basal Rate (U/h)                     0
# BWZ Estimate (U)                     0
# BWZ Carb Ratio (U/Ex)                0
# BWZ Insulin Sensitivity (mg/dL/U)    0
# BWZ Carb Input (exchanges)           0
# BWZ BG Input (mg/dL)                 0
# BWZ Correction Estimate (U)          0
# BWZ Food Estimate (U)                0
# BWZ Active Insulin (U)               0
# BWZ Unabsorbed Insulin Total (U)     0
# day_of_month                         0
# day_of_week                          0
# month_of_year                        0
# hour                                 0
# dtype: int64

# %%
Data.describe().T
# Out:
#                                     count          mean           std   min  \
# Unnamed: 0                         4038.0   2018.500000   1165.814522   0.0
# Unnamed: 0.1                       4038.0  18935.478455  10450.101192   8.0
# Basal Rate (U/h)                   4038.0      0.884064      0.275452   0.0
# BWZ Estimate (U)                   4038.0      4.732244      2.404036   0.0
# BWZ Carb Ratio (U/Ex)              4038.0      0.875478      0.178613   0.5
# BWZ Insulin Sensitivity (mg/dL/U)  4038.0     49.548044      2.033907  40.0
# BWZ Carb Input (exchanges)         4038.0      5.433878      2.521635   0.0
# BWZ BG Input (mg/dL)               4038.0    101.255572     15.388103  70.0
# BWZ Correction Estimate (U)        4038.0      0.011392      0.051280   0.0
# BWZ Food Estimate (U)              4038.0      4.725483      2.404366   0.0
# BWZ Active Insulin (U)             4038.0      0.345592      0.808059   0.0
# ...

# %%
Data.corr()
# Out:
#                                    Unnamed: 0  Unnamed: 0.1  Basal Rate (U/h)  \
# Unnamed: 0                           1.000000      0.540058         -0.324355
# Unnamed: 0.1                         0.540058      1.000000         -0.315831
# Basal Rate (U/h)                    -0.324355     -0.315831          1.000000
# BWZ Estimate (U)                    -0.082585     -0.055216          0.133947
# BWZ Carb Ratio (U/Ex)               -0.062742     -0.044000          0.357882
# BWZ Insulin Sensitivity (mg/dL/U)    0.364877      0.342605         -0.519004
# BWZ Carb Input (exchanges)          -0.068617     -0.046986         -0.011075
# BWZ BG Input (mg/dL)                -0.100097     -0.028485          0.027332
# BWZ Correction Estimate (U)          0.170897      0.141792         -0.077546
# BWZ Food Estimate (U)               -0.084072     -0.056199          0.135003
# BWZ Active Insulin (U)              -0.039616     -0.022797          0.122522
# ...
